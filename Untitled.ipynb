# %%
import arxiv
import pandas as pd
import time

# %%
time1=time.time()
client = arxiv.Client(num_retries=5,page_size=1000)
search = arxiv.Search(
      query = 'math.AC',
      max_results = 6000,
      sort_by = arxiv.SortCriterion.SubmittedDate
    )
    
results=client.results(search)
time2=time.time()
print(time2-time1)
# Out:
# 0.0

# %%
import pandas as pd
from PyPDF2 import PdfReader
import time
from copy import deepcopy

reader=PdfReader("msc2020.pdf")
n_pages=len(reader.pages)
df=pd.DataFrame(columns=['class','subject'])

def isMSC_xx(string):                         #The head subject e.g. 14Gxx which itself divides into more refined subjects.        
    if len(string)==5 and string[0:2].isnumeric() and string[2].isupper() and string[3:5]=='xx':
        return True
    return False

for page_number in range(n_pages):
    page_content=reader.pages[page_number].extract_text().split("\n")  #Splitting the page into lines. 
    for line in page_content:
        line_reduced=line.split('[')[0]      #Avoiding expressions such as '[See also...]'
        head=line_reduced.split(' ')[0]
        if isMSC_xx(head):
            MSC=head[:3]
            description=line_reduced.removeprefix(head)
            df.loc[df.shape[0]]=[MSC,description]
                        
        
df
# Out:
#     class                                            subject
# 0     00A           General and miscellaneous speci
# c topics
# 1     00B   Conference proceedings and collections of art...
# 2     01A          History of mathematics and mathematicians
# 3     03A     Philosophical aspects of logic and foundations
# 4     03B                                      General logic
# ..    ...                                                ...
# 532   97K   Education of combinatorics, graph theory, pro...
# 533   97M   Education of mathematical modeling and applic...
# 534   97N                 Education of numerical mathematics
# 535   97P             Computer science (educational aspects)
# 536   97U   Educational material and media and educationa...
#
# [537 rows x 2 columns]

# %%
df['subject'][0]
# Out:
# ' General and miscellaneous speci\x0cc topics'

# %%
pd.read_csv('raw.csv')
# Out:
#         Unnamed: 0 primary_category  \
# 0                0          math.AC
# 1                1          math.AC
# 2                2          math.AC
# 3                3          math.CO
# 4                4          math.AC
# ...            ...              ...
# 157207      157207          math.PR
# 157208      157208          math.PR
# 157209      157209          eess.SP
# 157210      157210            cs.IT
# 157211      157211          stat.ML
#
#                                                     title  \
# 0       Conditions for Virtually Cohen--Macaulay Simpl...
# 1       Density functions for epsilon multiplicity and...
# 2       Conditions of multiplicity and applications fo...
# 3       Equivariant Ehrhart theory, commutative algebr...
# 4       On the arithmetic of ultraproducts of commutat...
# ...                                                   ...
# 157207  The replica-symmetric free energy for Ising sp...
# ...

# %%
time1=time.time()
double_list=list(map(lambda r:[r.primary_category,r.title,r.authors,r.entry_id,r.updated,r.categories[-1]],results))
time2=time.time()
print(time2-time1)
# Out:
# Bozo feed; consider handling: document declared as utf-8, but parsed as iso-8859-2
# Bozo feed; consider handling: document declared as utf-8, but parsed as iso-8859-2
# Bozo feed; consider handling: document declared as utf-8, but parsed as iso-8859-2
# 117.81090140342712

# %%
import regex

# %%
df1=pd.DataFrame(double_list,columns=['primary_category','title','authors','url','last_updated','MSC'])
df2=pd.DataFrame(double_list,columns=['primary_category','title','authors','url','last_updated','MSC'])
pd.concat([df1,df2],ignore_index=True)
# Out:
#       primary_category                                              title  \
# 0              math.AC  Conditions for Virtually Cohen--Macaulay Simpl...
# 1              math.AC  Density functions for epsilon multiplicity and...
# 2              math.AC  Conditions of multiplicity and applications fo...
# 3              math.CO  Equivariant Ehrhart theory, commutative algebr...
# 4              math.AC  On the arithmetic of ultraproducts of commutat...
# ...                ...                                                ...
# 11995          math.AC  The Cohen-Macaulayness of the bounded complex ...
# 11996          math.AC  On Ding injective, Ding projective, and Ding f...
# 11997          math.AC  Minimum distance functions of graded ideals an...
# 11998          math.AC  Examples of local Cohomology Modules for Ramif...
# 11999          math.AC  A Note on Associated Primes and Bockstein Homo...
#
#                                                  authors  \
# ...

# %%
data
# Out:
#             0                                                  1  \
# 0     math.AC  Conditions for Virtually Cohen--Macaulay Simpl...
# 1     math.AC  Density functions for epsilon multiplicity and...
# 2     math.AC  Conditions of multiplicity and applications fo...
# 3     math.CO  Equivariant Ehrhart theory, commutative algebr...
# 4     math.AC  On the arithmetic of ultraproducts of commutat...
# ...       ...                                                ...
# 5995  math.AC  The Cohen-Macaulayness of the bounded complex ...
# 5996  math.AC  On Ding injective, Ding projective, and Ding f...
# 5997  math.AC  Minimum distance functions of graded ideals an...
# 5998  math.AC  Examples of local Cohomology Modules for Ramif...
# 5999  math.AC  A Note on Associated Primes and Bockstein Homo...
#
#                                                       2  \
# 0                             [Jay Yang, Adam Van Tuyl]
# 1       [Suprajo Das, Sudeshna Roy, Vijaylaxmi Trivedi]
# ...

# %%
not False
# Out:
# True

# %%
counter=1
for r in results:
    counter+=1

# %%
remove_dollar_sign('$mm$a xx$yy7$x')
# Out:
# 'a xxx'

# %%
'$mm$a'.split('$')
# Out:
# ['', 'mm', 'a']

# %%
data=pd.read_csv('processed.csv')

def remove_dollar_sign(string):
    components=string.split('$')
    if components[0]=='' and components[-1]=='':
        return ''
    cleaned_string=''
    between_dollar_signs=False        
    for component in components:
        if not between_dollar_signs:
            cleaned_string+=component
            between_dollar_signs=True
        else:
            between_dollar_signs=False
    return cleaned_string

# %%
import re

# Python3 program to check if a string
# contains any special character

# import required package
import re

# Function checks if the string
# contains any special character
def run(string):

	# Make own character set and pass 
	# this as argument in compile method
	#regex = re.compile('[@_!#$%^&*()<>?/\|}{~:]')
	regex = re.compile('$')
	# Pass the string in search 
	# method of regex object. 
	if(regex.search(string) == None):
		return True
		
	else:
		return False
	

    
def math_environment(string):
    if '$' in string:
        return True
    return False

# %%
data['bad title']=data['title'].apply(math_environment)

# %%
data[data['bad title']==True]
# Out:
#        Unnamed: 0    primary_category  \
# 23             23       cond-mat.soft
# 41             41  cond-mat.stat-mech
# 45             45  cond-mat.stat-mech
# 75             75               cs.CC
# 88             88               cs.CC
# ...           ...                 ...
# 59351       59351             stat.CO
# 59352       59352             stat.CO
# 59373       59373             stat.ME
# 59438       59438             stat.ME
# 59533       59533             stat.ML
#
#                                                    title  \
# 23          Compatible director fields in $\mathbb{R}^3$
# 41     Generalized Gibbs ensemble of the Ablowitz-Lad...
# 45     An exactly solvable asymmetric $K$-exclusion p...
# 75     Failure of Feasible Disjunction Property for $...
# 88                        $\mathcal{P}\neq \mathcal{NP}$
# ...                                                  ...
# 59351  Improved expected $L_2$-discrepancy formulas o...
# ...

# %%
import unicodedata
text = u'Teichmüller'
print(unicodedata.normalize('NFD', text).encode('ascii', 'ignore'))
# Out:
# b'Teichmuller'

# %%
data['special']=data['title'].apply(lambda title: 'Teich' in title)

# %%
data[data['special']]['url']
# Out:
# 5038     http://arxiv.org/abs/2311.15244v1
# 10827    http://arxiv.org/abs/2006.09943v2
# 18197    http://arxiv.org/abs/2007.15149v1
# 18289    http://arxiv.org/abs/2006.01565v1
# 18300    http://arxiv.org/abs/2307.02775v1
# 18393    http://arxiv.org/abs/2010.11542v1
# 18758    http://arxiv.org/abs/2008.06818v2
# 18825    http://arxiv.org/abs/2211.03290v1
# 19020    http://arxiv.org/abs/1911.05290v2
# 19115    http://arxiv.org/abs/2305.05626v2
# 19212    http://arxiv.org/abs/2107.10172v1
# 20173    http://arxiv.org/abs/2010.11806v3
# 21210    http://arxiv.org/abs/1909.11551v1
# 21350    http://arxiv.org/abs/1705.08431v1
# 21515    http://arxiv.org/abs/2012.02214v2
# 22200    http://arxiv.org/abs/2308.13860v1
# 23414    http://arxiv.org/abs/2203.15741v1
# 31573    http://arxiv.org/abs/2208.04778v1
# 33028    http://arxiv.org/abs/2212.14780v2
# 33072    http://arxiv.org/abs/2309.06993v1
# 33209    http://arxiv.org/abs/2212.06581v1
# 33251    http://arxiv.org/abs/2004.04231v1
# ...

# %%
from unidecode import unidecode
unidecode('TeichmĂźller')
# Out:
# 'TeichmAzller'

# %%
'TeichmĂźller'.lower()
# Out:
# 'teichmăźller'

# %%
'TeichmĂźller'=='TeichmAzller'
# Out:
# False

# %%
import nltk

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\khash\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\khash\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
STOPWORDS = set(stopwords.words('english'))

# %%
len(STOPWORDS)
# Out:
# 179

# %%
'ddd*'.lower()
# Out:
# 'ddd*'

# %%
STOPWORDS
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
# ...

# %%
from nltk.corpus import stopwords
stopwords.words('english')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...
